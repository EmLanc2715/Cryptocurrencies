# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
import pandas as pd
import hvplot.pandas
from pathlib import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ## Deliverable 1: Preprocessing the Data for PCA

# %%
# Load the crypto_data.csv dataset.
file_path = "C:/Users/emili/Class/Cryptocurrencies/Challenge/crypto_data.csv"
crypto_df = pd.read_csv(file_path, index_col=0)
crypto_df.head(10)
# Out:
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337     3.14159E+11
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %%
crypto_df.shape
# Out:
# (1252, 6)

# %%
# Keep all the cryptocurrencies that are being traded

crypto_df = crypto_df[crypto_df.IsTrading !=0]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (1144, 6)
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337     3.14159E+11
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %%
# Keep all the cryptocurrencies that have a working algorithm

crypto_df = crypto_df[crypto_df.Algorithm.isna() == False]

crypto_df.head(10)
# Out:
#        CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 42      42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 365     365Coin       X11       True   PoW/PoS              NaN
# 404     404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 611   SixEleven   SHA-256       True       PoW              NaN
# 808         808   SHA-256       True   PoW/PoS     0.000000e+00
# 1337  EliteCoin       X13       True   PoW/PoS     2.927942e+10
# 2015  2015 coin       X11       True   PoW/PoS              NaN
# BTC     Bitcoin   SHA-256       True       PoW     1.792718e+07
# ETH    Ethereum    Ethash       True       PoW     1.076842e+08
# LTC    Litecoin    Scrypt       True       PoW     6.303924e+07
#
#      TotalCoinSupply
# 42                42
# 365       2300000000
# 404        532000000
# 611           611000
# 808                0
# 1337     3.14159E+11
# 2015               0
# BTC         21000000
# ETH                0
# LTC         84000000

# %%
# Remove the "IsTrading" column

crypto_df = crypto_df.drop(columns="IsTrading")
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (1144, 5)
#        CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42      42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 365     365Coin       X11   PoW/PoS              NaN      2300000000
# 404     404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 611   SixEleven   SHA-256       PoW              NaN          611000
# 808         808   SHA-256   PoW/PoS     0.000000e+00               0
# 1337  EliteCoin       X13   PoW/PoS     2.927942e+10     3.14159E+11
# 2015  2015 coin       X11   PoW/PoS              NaN               0
# BTC     Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# ETH    Ethereum    Ethash       PoW     1.076842e+08               0
# LTC    Litecoin    Scrypt       PoW     6.303924e+07        84000000

# %%
# Remove rows that have at least 1 null value

crypto_df = crypto_df[~(crypto_df.isna() == True).any(axis=1)]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (685, 5)
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 808                808         SHA-256   PoW/PoS     0.000000e+00
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 808                0
# 1337     3.14159E+11
# BTC         21000000
# ETH                0
# LTC         84000000
# DASH        22000000
# XMR                0
# ...

# %%
# Keep the rows were coins are mined

crypto_df = crypto_df[~(crypto_df.TotalCoinsMined <=0)]
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (532, 5)
#               CoinName       Algorithm ProofType  TotalCoinsMined  \
# 42             42 Coin          Scrypt   PoW/PoS     4.199995e+01
# 404            404Coin          Scrypt   PoW/PoS     1.055185e+09
# 1337         EliteCoin             X13   PoW/PoS     2.927942e+10
# BTC            Bitcoin         SHA-256       PoW     1.792718e+07
# ETH           Ethereum          Ethash       PoW     1.076842e+08
# LTC           Litecoin          Scrypt       PoW     6.303924e+07
# DASH              Dash             X11   PoW/PoS     9.031294e+06
# XMR             Monero  CryptoNight-V7       PoW     1.720114e+07
# ETC   Ethereum Classic          Ethash       PoW     1.133597e+08
# ZEC              ZCash        Equihash       PoW     7.383056e+06
#
#      TotalCoinSupply
# 42                42
# 404        532000000
# 1337     3.14159E+11
# BTC         21000000
# ETH                0
# LTC         84000000
# DASH        22000000
# XMR                0
# ETC        210000000
# ...

# %%
# Create a new DataFrame that holds only the cryptocurrencies names

crypto_name_df = pd.DataFrame(crypto_df.CoinName)
print(crypto_name_df.shape)
crypto_name_df.head(10)
# Out:
# (532, 1)
#               CoinName
# 42             42 Coin
# 404            404Coin
# 1337         EliteCoin
# BTC            Bitcoin
# ETH           Ethereum
# LTC           Litecoin
# DASH              Dash
# XMR             Monero
# ETC   Ethereum Classic
# ZEC              ZCash

# %%
#Drop the 'CoinName' column since its not going to be used on the clustering algorithm

crypto_df = crypto_df.drop(columns="CoinName")
print(crypto_df.shape)
crypto_df.head(10)
# Out:
# (532, 4)
#            Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 42            Scrypt   PoW/PoS     4.199995e+01              42
# 404           Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337             X13   PoW/PoS     2.927942e+10     3.14159E+11
# BTC          SHA-256       PoW     1.792718e+07        21000000
# ETH           Ethash       PoW     1.076842e+08               0
# LTC           Scrypt       PoW     6.303924e+07        84000000
# DASH             X11   PoW/PoS     9.031294e+06        22000000
# XMR   CryptoNight-V7       PoW     1.720114e+07               0
# ETC           Ethash       PoW     1.133597e+08       210000000
# ZEC         Equihash       PoW     7.383056e+06        21000000

# %%
# Use get_dummies() to create variables for text features

X = pd.get_dummies(crypto_df, columns=["Algorithm", "ProofType"])
print(X.shape)
X.head(10)
# Out:
# (532, 98)
#       TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 42       4.199995e+01              42                                 0
# 404      1.055185e+09       532000000                                 0
# 1337     2.927942e+10     3.14159E+11                                 0
# BTC      1.792718e+07        21000000                                 0
# ETH      1.076842e+08               0                                 0
# LTC      6.303924e+07        84000000                                 0
# DASH     9.031294e+06        22000000                                 0
# XMR      1.720114e+07               0                                 0
# ETC      1.133597e+08       210000000                                 0
# ZEC      7.383056e+06        21000000                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 42                0                  0                   0                0
# ...

# %%
# Standardize the data with StandardScaler()

scaler = StandardScaler()
crypto_scaled = scaler.fit_transform(X)
crypto_scaled[0:5]
# Out:
# array([[-0.11710816, -0.15287029, -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.07530656, -0.0433963 , -0.06142951, -0.06142951,
#         -0.0433963 , -0.0433963 , -0.19245009, -0.06142951, -0.09740465,
#         -0.0433963 , -0.11547005, -0.07530656, -0.0433963 , -0.0433963 ,
#         -0.15191091, -0.0433963 , -0.13118084, -0.0433963 , -0.0433963 ,
#         -0.08703883, -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.08703883, -0.08703883, -0.08703883,
#         -0.0433963 , -0.13118084, -0.13840913, -0.13840913, -0.0433963 ,
#         -0.06142951, -0.0433963 , -0.07530656, -0.18168574, -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.07530656, -0.15826614, -0.31491833,
#         -0.0433963 , -0.08703883, -0.07530656, -0.06142951,  1.38675049,
#         -0.0433963 , -0.0433963 , -0.06142951, -0.0433963 , -0.0433963 ,
#         -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 , -0.0433963 ,
# ...

# %% [markdown]
# ## Deliverable 2: Reducing Data Dimensions Using PCA

# %%
# Using PCA to reduce dimension to three principle components

pca = PCA(n_components=3)
crypto_pca = pca.fit_transform(crypto_scaled)
crypto_pca
# Out:
# array([[-0.33204475,  1.02943206, -0.54187427],
#        [-0.31539755,  1.02944751, -0.54233742],
#        [ 2.29533548,  1.60197127, -0.64945879],
#        ...,
#        [ 0.32960906, -2.27206992,  0.37609303],
#        [-0.17010284, -2.13936905,  0.29389004],
#        [-0.2876606 ,  0.79653822, -0.21669628]])

# %%
# Create a DataFrame with the three principal components

pcs_df = pd.DataFrame(crypto_pca, columns=["PC 1", "PC 2", "PC 3"], index=crypto_name_df.index)
pcs_df.head(10)
# Out:
#           PC 1      PC 2      PC 3
# 42   -0.332045  1.029432 -0.541874
# 404  -0.315398  1.029448 -0.542337
# 1337  2.295335  1.601971 -0.649459
# BTC  -0.145714 -1.306221  0.207902
# ETH  -0.153906 -2.041664  0.399050
# LTC  -0.160068 -1.121126  0.022176
# DASH -0.400538  1.238025 -0.567195
# XMR  -0.151834 -2.215883  0.461585
# ETC  -0.152349 -2.041774  0.399024
# ZEC  -0.170102 -2.139369  0.293890

# %% [markdown]
# ## Deliverable 3: Clustering Cryptocurrencies Using K-Means
#
# ### Finding the Best Value for k Using the Elbow Curve

# %%
# Create an elbow curve to find the best value for K

# Initialize empty inertia list
inertia = []

#Initialize k range
k = list(range(1,11))

#Looping through the k list

for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)
# Out:
# C:\Users\emili\anaconda3\envs\mlenv\lib\site-packages\sklearn\cluster\_kmeans.py:1037: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   "KMeans is known to have a memory leak on Windows "

# %%
# Define a DataFrame to plot the Elbow Curve

elbow_data = {"k" : k, "inertia": inertia}
elbow_df = pd.DataFrame(elbow_data)
elbow_df.hvplot.line(x="k", y="inertia", title="Elbow Curve", xticks=k)
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# ### Running K-Means with k=4

# %%
# Initialize the K-Means model.
km_model = KMeans(n_clusters=4, random_state=0)

# Fit the model
km_model.fit(pcs_df)

# Predict clusters
predictions = km_model.predict(pcs_df)
predictions
# Out:
# array([0, 0, 0, 2, 2, 2, 0, 2, 2, 2, 0, 2, 0, 0, 2, 0, 2, 2, 0, 0, 2, 2,
#        2, 2, 2, 0, 2, 2, 2, 0, 2, 0, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 0, 0,
#        2, 2, 2, 2, 2, 0, 0, 2, 0, 2, 2, 2, 2, 0, 2, 2, 0, 2, 0, 0, 0, 2,
#        2, 2, 0, 0, 0, 0, 0, 2, 2, 2, 0, 0, 2, 0, 2, 0, 0, 2, 2, 2, 2, 0,
#        0, 2, 0, 2, 2, 0, 0, 2, 0, 0, 2, 2, 0, 0, 2, 0, 0, 2, 0, 2, 0, 2,
#        0, 2, 0, 0, 2, 2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 0,
#        2, 0, 2, 2, 0, 2, 0, 2, 0, 0, 2, 2, 0, 2, 2, 0, 0, 2, 0, 2, 0, 0,
#        0, 2, 2, 2, 2, 0, 0, 0, 0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 0, 0, 0, 0,
#        0, 2, 0, 2, 0, 0, 2, 0, 2, 0, 0, 2, 0, 2, 0, 2, 0, 2, 0, 0, 0, 0,
#        2, 0, 0, 0, 0, 0, 2, 2, 0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 0, 0, 0, 0,
#        0, 0, 0, 0, 2, 0, 0, 0, 0, 0, 0, 2, 2, 2, 0, 0, 0, 0, 2, 0, 2, 0,
#        0, 2, 0, 2, 2, 0, 2, 2, 0, 2, 0, 0, 0, 2, 0, 0, 2, 0, 0, 0, 0, 0,
#        0, 0, 2, 0, 2, 0, 0, 0, 0, 2, 0, 2, 0, 2, 2, 2, 2, 0, 2, 0, 0, 2,
# ...

# %%
# Create a new DataFrame including predicted clusters and cryptocurrencies features.
# Concatentate the crypto_df and pcs_df DataFrames on the same columns

clustered_df = pd.concat([crypto_df], axis=1, join='inner')

# Add a new column, "CoinName" to the clustered_df DataFrame that holds the predictions

clustered_df["CoinName"] = crypto_name_df.CoinName

# Add a new column, "Class" to the clustered_df DatFrame that holds the predicitons

clustered_df["Class"] = km_model.labels_

# Print the shape of the clustered_df

print(clustered_df.shape)
clustered_df.head(10)
# Out:
# (532, 6)
#            Algorithm ProofType  TotalCoinsMined TotalCoinSupply  \
# 42            Scrypt   PoW/PoS     4.199995e+01              42
# 404           Scrypt   PoW/PoS     1.055185e+09       532000000
# 1337             X13   PoW/PoS     2.927942e+10     3.14159E+11
# BTC          SHA-256       PoW     1.792718e+07        21000000
# ETH           Ethash       PoW     1.076842e+08               0
# LTC           Scrypt       PoW     6.303924e+07        84000000
# DASH             X11   PoW/PoS     9.031294e+06        22000000
# XMR   CryptoNight-V7       PoW     1.720114e+07               0
# ETC           Ethash       PoW     1.133597e+08       210000000
# ZEC         Equihash       PoW     7.383056e+06        21000000
#
#               CoinName  Class
# 42             42 Coin      0
# 404            404Coin      0
# 1337         EliteCoin      0
# BTC            Bitcoin      2
# ETH           Ethereum      2
# LTC           Litecoin      2
# DASH              Dash      0
# ...

# %% [markdown]
# ## Deliverable 4: Visualizing Cryptocurrencies Results
#
# ### 3D-Scatter with Clusters

# %%
# Creating a 3D-Scatter with the PCA data and the clusters
fig = px.scatter_3d(clustered_df, x="PC 1", y="PC 2", z="PC 3", color="Class", symbol="Class", width=800, 
                    hover_name="CoinName", hover_data=["Algorithm"])
fig.update_layout(legend=dict(x=0, y=1))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6456\3254252912.py in <module>
#       1 # Creating a 3D-Scatter with the PCA data and the clusters
#       2 fig = px.scatter_3d(clustered_df, x="PC 1", y="PC 2", z="PC 3", color="Class", symbol="Class", width=800,
# ----> 3                     hover_name="CoinName", hover_data=["Algorithm"])
#       4 fig.update_layout(legend=dict(x=0, y=1))
#       5 fig.show()
#
# ...

# %%
# Create a table with tradable cryptocurrencies.

tradable_crypto_table = clustered_df.hvplot.table(columns=['CoinName', 'Algorithm', 'ProofType', 'TotalCoinSupply', 
                                                  'TotalCoinsMined', 'Class'], sortable=True, selectable=True)
tradable_crypto_table
# Out:
# :Table   [CoinName,Algorithm,ProofType,TotalCoinSupply,TotalCoinsMined,Class]

# %%
# Print the total number of tradable cryptocurrencies.

print(f'There are {len(clustered_df)} tradable cryptocurrencies.')
# Out:
# There are 532 tradable cryptocurrencies.

# %%
# Scaling data to create the scatter plot with tradable cryptocurrencies.
X_cluster = clustered_df[['TotalCoinSupply', 'TotalCoinsMined']].copy()
X_cluster_scaled = MinMaxScaler().fit_transform(X_cluster)
X_cluster_scaled
# Out:
# array([[4.20000000e-11, 0.00000000e+00],
#        [5.32000000e-04, 1.06585514e-03],
#        [3.14159000e-01, 2.95755050e-02],
#        ...,
#        [1.40022261e-03, 9.90134792e-04],
#        [2.10000000e-05, 7.37027937e-06],
#        [1.00000000e-06, 1.29582244e-07]])

# %%
# Create a new DataFrame that has the scaled data with the clustered_df DataFrame index.
plot_df = pd.DataFrame(X_cluster_scaled, columns=['TotalCoinSupply', 'TotalCoinsMined'], index=clustered_df.index)

# Add the "CoinName" column from the clustered_df DataFrame to the new DataFrame.
plot_df['CoinName'] = clustered_df.CoinName

# Add the "Class" column from the clustered_df DataFrame to the new DataFrame. 
plot_df['Class'] = clustered_df.Class

plot_df.head(10)
# Out:
#       TotalCoinSupply  TotalCoinsMined          CoinName  Class
# 42       4.200000e-11         0.000000           42 Coin      0
# 404      5.320000e-04         0.001066           404Coin      0
# 1337     3.141590e-01         0.029576         EliteCoin      0
# BTC      2.100000e-05         0.000018           Bitcoin      2
# ETH      0.000000e+00         0.000109          Ethereum      2
# LTC      8.400000e-05         0.000064          Litecoin      2
# DASH     2.200000e-05         0.000009              Dash      0
# XMR      0.000000e+00         0.000017            Monero      2
# ETC      2.100000e-04         0.000115  Ethereum Classic      2
# ZEC      2.100000e-05         0.000007             ZCash      2

# %%
# Create a hvplot.scatter plot using x="TotalCoinsMined" and y="TotalCoinSupply".

plot_df.hvplot.scatter(x='TotalCoinsMined', y='TotalCoinSupply', hover_cols='CoinName', by='Class')
# Out:
# :NdOverlay   [Class]
#    :Scatter   [TotalCoinsMined]   (TotalCoinSupply,CoinName)
